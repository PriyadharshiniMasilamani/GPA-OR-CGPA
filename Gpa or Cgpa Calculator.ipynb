# %%
print("                              ANNA UNIVERSITY                       ")
Name=input("Name of the candidate:")
Reg_no=int(input("Register Number:"))
import datetime
Dob=input("Date of Birth:",)
day=Dob.find("/")
month=Dob.find("/")
year=Dob.find("/")
Deg=input("Degree & Branch:")
Year=int(input("Year of the Degree:"))
college=input("College of study:")
gpa_or_cgpa=input("GPA OR CGPA   :    ")
gpa=0
if(gpa_or_cgpa.lower()=="gpa"):
    no_of_semester=int(input("Enter the semester:"))
    no_of_subjects=int(input("Enter total no of subjects : "))
    sum_1=0
    grade_to_point=0
    for i in range(0,no_of_subjects):
        grade=input("Enter subject grade : ")
        cradit=int(input("Enter credit value for the above subject : "))
        if(grade.upper()=="O"):
            point=10
            print("PASS")
        elif(grade.upper()=="A+"):
            point=9
            print("PASS")
        elif(grade.upper()=="A"):
            point=8
            print("PASS")
        elif(grade.upper()=="B+"):
            point=7
            print("PASS")
        elif(grade.upper()=="B"):
            point=6
            print("PASS")
        else:
            point=0
            print("RA*")
        
        if(point==0):
            cradit=0
        grade_to_point=grade_to_point+(point*cradit)
        sum_1=sum_1+cradit
        gpa=grade_to_point/sum_1
    print("\n")    
    print("GRADE POINT AVERAGE:",(gpa),"\n")
    print("*** END OF THE STATEMENT***")


elif(gpa_or_cgpa.lower()=="cgpa"):
    no_of_subjects=int(input("Enter total no of subjects : "))
    sum_1=0
    grade_to_point=0
    for i in range(0,no_of_subjects):
        grade=input("Enter grade : ")
        cradit=int(input("Enter credit value for the above subject : "))
        if(grade.upper()=="O"):
            point=10
        elif(grade.upper()=="A+"):
            point=9
        elif(grade.upper()=="A"):
            point=8
        elif(grade.upper()=="B+"):
            point=7
        elif(grade.upper()=="B"):
            point=6
        else:
            point=0
        
        if(point==0):
            cradit=0
        grade_to_point=grade_to_point+(point*cradit)
        sum_1=sum_1+cradit
    gpa=grade_to_point/sum_1
    prev_cgpa=float(input("Enter previous cgpa  :   ",))
    print("\n")
    cgpa=(prev_cgpa+gpa)/2
    if(cgpa>=8):
        print("CLASSIFICATION: FIRST CLASS","\n")
    elif(cgpa>5 and cgpa<8):
        print("CLASSIFICATION: SECOND CLASS","\n")
    print("CUMULATIVE GRADE POINT AVERAGE:",cgpa,"\n")  
    print("                          *** END OF THE STATEMENT***        ")
else:
    print("Invalid Input")
# Out:
#                               ANNA UNIVERSITY
